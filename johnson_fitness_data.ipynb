# %%
import pandas as pd

df = pd.read_excel("preprocessed.xlsx", index_col= None)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23875 entries, 0 to 23874
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Customer                 23875 non-null  object
#  1   Date                     23875 non-null  datetime64[ns]
#  2   Sales Order              23871 non-null  object
#  3   Legacy Job Order Number  23875 non-null  object
#  4   Project Name             22780 non-null  object
#  5   Segment                  23875 non-null  object
#  6   Region                   23875 non-null  object
#  7   Salesperson              23875 non-null  object
#  8   Material                 22750 non-null  object
#  9   Brand                    23875 non-null  object
#  10  Product Category         23875 non-null  object
#  11  Product Description      23875 non-null  object
#  12  Quantity                 23875 non-null  float64
# ...
